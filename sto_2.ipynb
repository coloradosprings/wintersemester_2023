# %%
from sympy import *

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
points = np.linspace(0,5,30)

# %%
fig, ax = plt.subplots()
ax.plot(points,-np.sqrt(points))
ax.plot(points,-np.sqrt(points - 1),"r")
ax.plot(points,-points,"r")

plt.grid("True")
# Out:
# C:\Users\natsc\AppData\Local\Temp\ipykernel_21428\57300810.py:3: RuntimeWarning: invalid value encountered in sqrt
#   ax.plot(points,-np.sqrt(points - 1),"r")

# %%
fig, ax = plt.subplots()
ax.plot(points,-points)
ax.plot(points,-np.sqrt(points**2 - 2),"r")
# Out:
# C:\Users\natsc\AppData\Local\Temp\ipykernel_21428\831164895.py:3: RuntimeWarning: invalid value encountered in sqrt
#   ax.plot(points,-np.sqrt(points**2 - 2),"r")

# %%
a,b,c,d,e,f = symbols("a b c d e f")

# %%
char = 1  - ( 1 - a + b - 2 *c) * (1 - (d)*(e)) * (1 - ((1 - a)*(1 - b)) * (d + e - 2*f))

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
x1=np.array([1,1,1])
x2=np.array([1,2,2])
x3=np.array([1,3,3])
x4=np.array([1,4,5])
x5=np.array([1,4,6])

# %%
for x in X:
    x = np.array(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\share\sto_2.ipynb Cell 10 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/share/sto_2.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> for x in X:
#       <a href='vscode-notebook-cell:/d%3A/share/sto_2.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a>     x = np.array(x)
#
# NameError: name 'X' is not defined

# %%
X = np.array([x1,x2,x3,x3,x4])
y=np.array([2,3/2,4,2,5])

# %%
 X.T @ X
# Out:
# array([[ 5, 13, 14],
#        [13, 39, 43],
#        [14, 43, 48]])

# %%
X.T @ y
# Out:
# array([14.5, 43. , 48. ])

# %%
np.linalg.solve(X.T @ X,X.T@y)
# Out:
# array([ 1.04545455, -1.        ,  1.59090909])

# %%
linear_regression = LinearRegression()
linear_regression.fit(X,y)
# Out:
# LinearRegression()

# %%
linear_regression.coef_
#linear_regression.intercept_
# Out:
# array([ 0.        , -1.        ,  1.59090909])

# %%
linear_regression.predict(X)
# Out:
# array([1.63636364, 2.22727273, 2.81818182, 2.81818182, 5.        ])

# %%
(2**-(a+1)**b/2**-(a)**b).simplify()
# Out:
# 2**(a**b - (a + 1)**b)

# %%
for k in range(1,10):
    print(limit(a**(k/10) - (a + 1)**(k/10 ),a,oo))
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
Derivative(2**a**b,a).simplify()
# Out:
# 2**(a**b)*a**b*b*log(2)/a

# %%
x = Symbol("x",min = -2 ,max=2)

# %%
solve(-x + 2**(3/2)*sqrt(x) + 2)
# Out:
# [11.6568542494924]

# %%
help(Symbol)
# Out:
# Help on class Symbol in module sympy.core.symbol:
#
# class Symbol(sympy.core.expr.AtomicExpr, sympy.logic.boolalg.Boolean)
#  |  Symbol(name, **assumptions)
#  |
#  |  Assumptions:
#  |     commutative = True
#  |
#  |  You can override the default assumptions in the constructor.
#  |
#  |  Examples
#  |  ========
#  |
#  |  >>> from sympy import symbols
#  |  >>> A,B = symbols('A,B', commutative = False)
#  |  >>> bool(A*B != B*A)
#  |  True
#  |  >>> bool(A*B*2 == 2*A*B) == True # multiplication by scalars is commutative
#  |  True
#  |
#  |  Method resolution order:
#  |      Symbol
#  |      sympy.core.expr.AtomicExpr
#  |      sympy.core.basic.Atom
#  |      sympy.core.expr.Expr
#  |      sympy.logic.boolalg.Boolean
#  |      sympy.core.basic.Basic
#  |      sympy.printing.defaults.Printable
#  |      sympy.core.evalf.EvalfMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getnewargs_ex__(self)
#  |
#  |  __new_stage2__(cls, name, **assumptions)
#  |
# ...
